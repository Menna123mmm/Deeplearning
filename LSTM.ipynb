# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def tanh(x):
    return np.tanh(x)

Wf, Whf, bf = 0.5, 0.1, 0
Wi, Whi, bi = 0.6, 0.2, 0
Wc, Whc, bc = 0.7, 0.3, 0
Wo, Who, bo = 0.8, 0.4, 0

Hidden= 0 
Cell= 0 

X = [1, 2, 3, 4]
for t, x in enumerate(X):
    Forget= sigmoid(Wf * x + Whf * Hidden + bf)
    Input= sigmoid(Wi * x + Whi * Hidden + bi)
    Candidate= tanh(Wc * x + Whc * Hidden + bc)
    Cell= (Forget* Cell) + (Input*Candidate)
    Output= sigmoid(Wo * x + Who * Hidden+ bo)
    Hidden=Output* tanh(Cell)
    
    print(f"t={t+1}  x={x}  Forget= {Forget}  Input={Input} Candidate={Candidate}  Cell={Cell}  Output={Output}  Hidden_state_update={ Hidden_state_update}")
Wy, by = 4, 0
y_pred = Wy *  Hidden_state_update + by
print(y_pred)
# Out:
# t=1  x=1  Forget_gate=0.6224593312018546  Input_gate=0.6456563062257954 Candidate_cell_state=0.6043677771171634  Cell_state_update=0.3902138665753625  Output_gate=0.6899744811276125  Hidden_state_update=0.25635628280714157
# t=2  x=2  Forget_gate=0.7360688968990954  Input_gate=0.7775198441930913 Candidate_cell_state=0.9008868572585005  Cell_state_update=0.9876816992160908  Output_gate=0.8458665100900064  Hidden_state_update=0.6397897934352906
# t=3  x=3  Forget_gate=0.8269235694009454  Input_gate=0.8730232244740167 Candidate_cell_state=0.9797760982564457  Cell_state_update=1.672104564710174  Output_gate=0.9343746800221002  Hidden_state_update=0.8706777856279052
# t=4  x=4  Forget_gate=0.889639866611438  Input_gate=0.929178323745328 Candidate_cell_state=0.9956232562217189  Cell_state_update=2.4126824302070977  Output_gate=0.972030460916739  Hidden_state_update=0.9565562031381949
# 3.8262248125527796

# %%
# Out:
# Step       | Input  | h_t        | C_t
# ---------------------------------------------
# Time t=1  | x=1     | h=0.256    | C=0.390
# Time t=2  | x=2     | h=0.640    | C=0.988
# Time t=3  | x=3     | h=0.871    | C=1.672
# Time t=4  | x=4     | h=0.957    | C=2.413
# ---------------------------------------------
# Final Prediction (y_hat): 3.826
