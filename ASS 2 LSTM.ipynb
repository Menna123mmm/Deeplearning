# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def tanh(x):
    return np.tanh(x)

Wf, Whf, bf = 0.5, 0.1, 0
Wi, Whi, bi = 0.6, 0.2, 0
Wc, Whc, bc = 0.7, 0.3, 0
Wo, Who, bo = 0.8, 0.4, 0

H= 0 
C= 0 

X = [1, 2, 3, 4]
for t, x in enumerate(X):
    F= sigmoid(Wf * x + Whf * H + bf)
    I= sigmoid(Wi * x + Whi * H + bi)
    Candi= tanh(Wc * x + Whc * H + bc)
    C= (F* C) + (I*Candi)
    O= sigmoid(Wo * x + Who * H+ bo)
    H=O* tanh(Cell)
    
    print(f"x={x} F= {F}  I={I} Candi={Candi}  C={C}  O={O}  Hi={ Hidden}")
Wy, by = 4, 0
y_pred = Wy *  Hidden + by
print(y_pred)
# Out:
# x=1  Forget= 0.6224593312018546  Input=0.6456563062257954 Candidate=0.6043677771171634  Cell=0.3902138665753625  Output=0.6899744811276125  Hidden=0.25635628280714157
# x=2  Forget= 0.7360688968990954  Input=0.7775198441930913 Candidate=0.9008868572585005  Cell=0.9876816992160908  Output=0.8458665100900064  Hidden=0.6397897934352906
# x=3  Forget= 0.8269235694009454  Input=0.8730232244740167 Candidate=0.9797760982564457  Cell=1.672104564710174  Output=0.9343746800221002  Hidden=0.8706777856279052
# x=4  Forget= 0.889639866611438  Input=0.929178323745328 Candidate=0.9956232562217189  Cell=2.4126824302070977  Output=0.972030460916739  Hidden=0.9565562031381949
# 3.8262248125527796
